# %% [markdown]
# Project
#
# Authors: Sarika, Jacob, and Didem1

# %%
#library dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
import matplotlib.pyplot as plt
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
import scipy.stats as st
from scipy.stats import linregress

# !pip install hvplot geoviews
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b668b40e-7b3e-4985-85fc-57dc27ecd677" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a063c9fb-4590-4f46-bf7a-2e5b0d0b0998":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"437e1b03ac3748debf950b99ee36a3fc","client_comm_id":"b90efb0829c74b75bdc9ede594d7b77a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"a063c9fb-4590-4f46-bf7a-2e5b0d0b0998","roots":{"p1002":"b668b40e-7b3e-4985-85fc-57dc27ecd677"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# Requirement already satisfied: hvplot in c:\users\didem\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: geoviews in c:\users\didem\anaconda3\lib\site-packages (1.12.0)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (3.4.1)
# Requirement already satisfied: colorcet>=2 in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (1.19.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (1.26.4)
# Requirement already satisfied: packaging in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (23.2)
# Requirement already satisfied: pandas in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=0.11.0 in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (1.4.4)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\didem\anaconda3\lib\site-packages (from hvplot) (2.1.0)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\didem\anaconda3\lib\site-packages (from geoviews) (0.23.0)
# Requirement already satisfied: shapely in c:\users\didem\anaconda3\lib\site-packages (from geoviews) (2.0.5)
# Requirement already satisfied: pyproj in c:\users\didem\anaconda3\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\didem\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\didem\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\didem\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\didem\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\didem\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\didem\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.4.1)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\didem\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.4)
# Requirement already satisfied: pyshp>=2.3 in c:\users\didem\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\didem\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\didem\anaconda3\lib\site-packages (from pandas->hvplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\didem\anaconda3\lib\site-packages (from pandas->hvplot) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\didem\anaconda3\lib\site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: markdown in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.66.4)
# Requirement already satisfied: bleach in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\didem\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.11.0)
# Requirement already satisfied: certifi in c:\users\didem\anaconda3\lib\site-packages (from pyproj->geoviews) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\didem\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\didem\anaconda3\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\didem\anaconda3\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\didem\anaconda3\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\didem\anaconda3\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\didem\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\didem\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\didem\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\didem\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\didem\anaconda3\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\didem\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\didem\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\didem\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.2.2)

# %%
# Import cities file as DataFrame
mp_df=pd.read_csv("../Resources/chicago_public_health.csv")

# %%
# List of Regions with corresponding Community areas for data manipulation
RA=[{"Far North Side":["Rogers Park","West Ridge","Uptown","Lincoln Square","O'Hare","Edgewater","North Park","Albany Park","Edison Park","Norwood Park","Jefferson Park","Forest Glen"]},
{"Northwest Side":["North Center","Lake View","Lincoln Park","Avondale","Logan Square","Hermosa","Portage Park","Irving Park","Dunning","Montclaire","Belmont Cragin"]},
{"North Side":["Near North Side","West Town","Humboldt Park","Austin"]},
{"Central":["Loop","Near South Side","Near West Side"]},
{"West Side":["East Garfield Park","West Garfield Park","North Lawndale","South Lawndale","Lower West Side"]},
{"South Side":["Greater Grand Crossing","Armour Square","Douglas","Oakland","Fuller Park","Grand Boulevard","Kenwood","Washington Park","Hyde Park","Woodlawn","South Shore"]},
{"Southwest Side":["Bridgeport","New City","West Elsdon","Gage Park","Brighton Park","McKinley Park","Archer Heights","West Lawn","Chicago Lawn","Garfield Ridge","Clearing","West Englewood","Englewood"]},
{"Far Southwest Side":["Washington Heights","Auburn Gresham","Ashburn","Beverly","Mount Greenwood","Morgan Park"]},
{"Far Southeast Side":["Chatham","Avalon Park","South Chicago","Burnside","Calumet Heights","Roseland","Pullman","South Deering","East Side","West Pullman","Riverdale","Hegewisch"]}]

#Add a new column for Region
mp_df["Region"]=""

#Populate the new column - Region

for i in range(mp_df.shape[0]):
    cma=mp_df.loc[i,"Community Area Name"]
    for r in range(len(RA)):
        k=list(RA[r])[0]
        if cma in RA[r][k]:
            mp_df.loc[i,"Region"]=k
            #print(cma,k)
            
#reorganize columns
column_to_move = mp_df.pop('Region')
mp_df.insert(2, 'Region', column_to_move)


#clean the data frame
clean_df = mp_df[["Region","Community Area Name","Per Capita Income","Below Poverty Level",
       "Birth Rate", "General Fertility Rate", "Low Birth Weight",
        "Prenatal Care Beginning in First Trimester", "Preterm Births",
       "Teen Birth Rate", "Diabetes-related", "Infant Mortality Rate","Childhood Lead Poisoning","Tuberculosis",
        "Crowded Housing","No High School Diploma"]]

clean_df
# Out:
#                 Region Community Area Name  Per Capita Income  \
# 0       Far North Side         Rogers Park              23714
# 1       Far North Side          West Ridge              21375
# 2       Far North Side              Uptown              32355
# 3       Far North Side      Lincoln Square              35503
# 4       Northwest Side        North Center              51615
# ..                 ...                 ...                ...
# 72  Far Southwest Side  Washington Heights              19709
# 73  Far Southwest Side     Mount Greenwood              34221
# 74  Far Southwest Side         Morgan Park              26185
# 75      Far North Side              O'Hare              29402
# 76      Far North Side           Edgewater              33364
#
#     Below Poverty Level  Birth Rate  General Fertility Rate  Low Birth Weight  \
# 0                  22.7        16.4                    62.0              11.0
# 1                  15.1        17.3                    83.3               8.1
# 2                  22.7        13.1                    50.5               8.3
# 3                   9.5        17.1                    61.0               8.1
# 4                   7.1        22.4                    76.2               9.1
# ..                  ...         ...                     ...               ...
# 72                 15.7        12.0                    61.0              19.6
# 73                  3.1        12.5                    59.0               8.4
# 74                 13.7        13.2                    67.5              10.6
# 75                  9.5        15.8                    70.0               3.5
# 76                 16.6        12.1                    48.1               7.5
#
#     Prenatal Care Beginning in First Trimester  Preterm Births  \
# 0                                         73.0            11.2
# 1                                         71.1             8.3
# 2                                         77.7            10.3
# 3                                         80.5             9.7
# 4                                         80.4             9.8
# ..                                         ...             ...
# 72                                        75.4            16.2
# 73                                        94.5            15.1
# 74                                        74.5            12.3
# 75                                        82.0             5.0
# 76                                        76.1             7.4
#
#     Teen Birth Rate  Diabetes-related  Infant Mortality Rate  \
# 0              40.8              77.1                    6.4
# 1              29.9              60.5                    5.1
# 2              35.1              80.0                    6.5
# 3              38.4              55.4                    3.8
# 4               8.4              49.8                    2.7
# ..              ...               ...                    ...
# 72             65.0              79.5                   11.2
# 73              7.7              66.5                    3.3
# 74             46.7              75.4                   13.1
# 75             15.9              47.3                    2.0
# 76             15.1              48.8                    6.9
#
#     Childhood Lead Poisoning  Tuberculosis  Crowded Housing  \
# 0                        0.5          11.4              7.9
# 1                        1.0           8.9              7.0
# 2                        0.5          13.6              4.6
# 3                        0.4           8.5              3.1
# 4                        0.9           1.9              0.2
# ..                       ...           ...              ...
# 72                       1.5           3.0              1.1
# 73                       0.0           0.0              1.1
# 74                       1.3           2.6              0.8
# 75                       0.5           6.3              1.9
# 76                       0.9          10.5              3.9
#
#     No High School Diploma
# 0                     18.1
# 1                     19.6
# 2                     13.6
# 3                     12.5
# 4                      5.4
# ..                     ...
# 72                    15.6
# 73                     4.5
# 74                    10.9
# 75                    11.0
# 76                     9.0
#
# [77 rows x 16 columns]

# %% [markdown]
# ## DataFrame Preparation

# %%
#regression function
def get_regress(x,y, title, xlabel, ylabel):
   plt.scatter(x=x,y=y)
   (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
   regress_values = x * slope + intercept
   line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
   plt.plot(x,regress_values, color='red')
   plt.title(title)
   plt.xlabel(xlabel)
   plt.ylabel(ylabel)
   if sum(x) > 0:
      plt.annotate(line_eq,(min(x),min(y)),fontsize=15,color='red')
   else: 
      plt.annotate(line_eq,(min(x),min(y)),fontsize=15,color='red')
   print(f'The r-squared is: {rvalue**2}')
   print(f'The r-value is {rvalue}')
   print(f'The p-value is {pvalue}')
   print(f'The stderr is {stderr}')
   
   plt.show()

# %% [markdown]
# Q1 - Which community areas have high teen birth rates, and is there a correlation between a lack of a high school diploma and elevated rates of teen births or preterm births?
# Sarika

# %% [markdown]
# Q2 - Do higher rates of poverty/lower average income result in higher prevalence of childhood lead poisoning?
# Jacob

# %% [markdown]
# Q3- Do certain socioeconomic brackets have a higher risk of certain health markers? Diabetes
# Didem

# %%
# Make a copy of the dataset
econ_clean_df = clean_df.copy()

# %%
#Make a scatter plot to understand the relationship, if any, between per capita income and diabetes-related deaths

diabetes_na_df = econ_clean_df.loc[(~econ_clean_df['Per Capita Income'].isna()) & (~econ_clean_df['Diabetes-related'].isna())]

get_regress(diabetes_na_df['Per Capita Income'],diabetes_na_df['Diabetes-related'],'Per Capita Income vs. Diabetes-Related','Per Capita','Diabetes')
# Out:
# The r-squared is: 0.36224641349477216
# The r-value is -0.6018690999667388
# The p-value is 7.055262629933287e-09
# The stderr is 0.00013257909326109304

# %%
plt.savefig("../Out/Didemfig1.png")

# %%
#Get the minimum and maximum per capita income to determine the number of bins
print(econ_clean_df["Per Capita Income"].max())
print(econ_clean_df["Per Capita Income"].min())
# Out:
# 87163
# 8535

# %%
# Establish the bins
econ_clean_df = clean_df.copy()
bins = [0, 30000, 60000, 90000]
group_labels = ["<$30000", "$30000-60000", "$60000-90000"]
ranges = econ_clean_df["Per Capita Income"]
econ_clean_df["Per Capita Income Ranges"] = pd.cut(econ_clean_df["Per Capita Income"], bins, labels=group_labels, right=False)


econ_clean_df.head(77)
# Out:
#                 Region Community Area Name  Per Capita Income  \
# 0       Far North Side         Rogers Park              23714
# 1       Far North Side          West Ridge              21375
# 2       Far North Side              Uptown              32355
# 3       Far North Side      Lincoln Square              35503
# 4       Northwest Side        North Center              51615
# ..                 ...                 ...                ...
# 72  Far Southwest Side  Washington Heights              19709
# 73  Far Southwest Side     Mount Greenwood              34221
# 74  Far Southwest Side         Morgan Park              26185
# 75      Far North Side              O'Hare              29402
# 76      Far North Side           Edgewater              33364
#
#     Below Poverty Level  Birth Rate  General Fertility Rate  Low Birth Weight  \
# 0                  22.7        16.4                    62.0              11.0
# 1                  15.1        17.3                    83.3               8.1
# 2                  22.7        13.1                    50.5               8.3
# 3                   9.5        17.1                    61.0               8.1
# 4                   7.1        22.4                    76.2               9.1
# ..                  ...         ...                     ...               ...
# 72                 15.7        12.0                    61.0              19.6
# 73                  3.1        12.5                    59.0               8.4
# 74                 13.7        13.2                    67.5              10.6
# 75                  9.5        15.8                    70.0               3.5
# 76                 16.6        12.1                    48.1               7.5
#
#     Prenatal Care Beginning in First Trimester  Preterm Births  \
# 0                                         73.0            11.2
# 1                                         71.1             8.3
# 2                                         77.7            10.3
# 3                                         80.5             9.7
# 4                                         80.4             9.8
# ..                                         ...             ...
# 72                                        75.4            16.2
# 73                                        94.5            15.1
# 74                                        74.5            12.3
# 75                                        82.0             5.0
# 76                                        76.1             7.4
#
#     Teen Birth Rate  Diabetes-related  Infant Mortality Rate  \
# 0              40.8              77.1                    6.4
# 1              29.9              60.5                    5.1
# 2              35.1              80.0                    6.5
# 3              38.4              55.4                    3.8
# 4               8.4              49.8                    2.7
# ..              ...               ...                    ...
# 72             65.0              79.5                   11.2
# 73              7.7              66.5                    3.3
# 74             46.7              75.4                   13.1
# 75             15.9              47.3                    2.0
# 76             15.1              48.8                    6.9
#
#     Childhood Lead Poisoning  Tuberculosis  Crowded Housing  \
# 0                        0.5          11.4              7.9
# 1                        1.0           8.9              7.0
# 2                        0.5          13.6              4.6
# 3                        0.4           8.5              3.1
# 4                        0.9           1.9              0.2
# ..                       ...           ...              ...
# 72                       1.5           3.0              1.1
# 73                       0.0           0.0              1.1
# 74                       1.3           2.6              0.8
# 75                       0.5           6.3              1.9
# 76                       0.9          10.5              3.9
#
#     No High School Diploma Per Capita Income Ranges
# 0                     18.1                  <$30000
# 1                     19.6                  <$30000
# 2                     13.6             $30000-60000
# 3                     12.5             $30000-60000
# 4                      5.4             $30000-60000
# ..                     ...                      ...
# 72                    15.6                  <$30000
# 73                     4.5             $30000-60000
# 74                    10.9                  <$30000
# 75                    11.0                  <$30000
# 76                     9.0             $30000-60000
#
# [77 rows x 17 columns]

# %%
#Group the mean of the number of diabetes-related deaths per 100,000 population by income range 

grouped_income_diabetes = econ_clean_df.groupby(["Per Capita Income Ranges"])["Diabetes-related"].mean()

reset_income_diabetes = grouped_income_diabetes.reset_index()


reset_income_diabetes.head(77)
# Out:
# C:\Users\didem\AppData\Local\Temp\ipykernel_32792\337434970.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_income_diabetes = econ_clean_df.groupby(["Per Capita Income Ranges"])["Diabetes-related"].mean()
#   Per Capita Income Ranges  Diabetes-related
# 0                  <$30000         77.777966
# 1             $30000-60000         56.064286
# 2             $60000-90000         41.350000

# %%
# Make a pie chart to show the distribution of diabetes-related mortality across income groups
labels = ["<$30000","$30000-60000","$60000-90000"]
colors = ["green","orange","purple"]
explode=[0.1,0,0]
diabetes_pie = reset_income_diabetes.plot(kind="pie", y="Diabetes-related", labels=labels, legend=False, colors=colors, explode=explode, ylabel="Diabetes-related deaths", autopct='%1.1f%%')
plt.title("Distribution of Diabetes-Related Deaths Across Income Groups")
plt.show()

# %%
plt.savefig("../Out/Didemfig2.png")

# %% [markdown]
# Analysis:
# Q3- Do certain socioeconomic brackets have a higher risk of certain health markers?:
#
# Part I: Linear Regression Analysis
#
# Null hypothesis: There is no relationship between per capita income (x/independent variable) and diabetes-related deaths (y/dependent variable).
# Alternate hypothesis: Per capita income and diabetes-related deaths are correlated.
#
# The results of the linear regression analysis of per capita income (PCI) vs. diabetes-related deaths per 100.000 population indicate a strong negative correlation between these two variables with an r-value of -0.6. The p-value is below the level of significance of 0.05, which suggests that there is sufficient evidence in our observed results to reject the null hypothesis. The coefficient of determination is relatively low, which indicates that only 36% of the variation in diabetes-related deaths can be explained by income. Further analysis is needed to understand other factors that might be affecting diabetes related mortality.
#
#
# The r-squared is: 0.36224641349477216
# The r-value is -0.6018690999667388
# The p-value is 7.055262629933287e-09
# The stderr is 0.00013257909326109
#
# Part II: Breakdown of Diabetes-Related Deaths by Income Range
#
# In the second part of the analysis, per capita income data is grouped under three income range groups: less than 30000 USD , 30000-60000 USD and 60000-90000 USD. The goal is to determine which income groups would benefit most from an intervention to reduce diabetes-related mortality. The mean of diabetes-related mortality is highest in communities with an average per capita income of less than 30.000 USD.
